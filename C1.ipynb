# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-32886514c262> in <module>()
# ----> 1 python
#
# NameError: name 'python' is not defined

# %%
variable ?? 
# in c/c++
int a = 4;
float b = 0.4;
printf()
cout<<

# %%
# integers
a = 7
b = 0.4
print(a)
print(b)
# Out:
# 7
# 0.4

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(id(a))
# Out:
# 94751793638080

# %%
print(id(b))
# Out:
# 139882638123344

# %%
# in c/c++
# int a = 4;
# float b = 0.4;

# sum = a+b
# printf(sum)
print(a+b)
print(7+0.4)
# Out:
# 7.4
# 7.4

# %%
# float
x = 1.0
type(x)

# %%
# boolean
b1 = True
b2 = False

type(b1) # ye jo jupyter notebook aur gColab
print(type(b1)) # vscode/sublime text
print(type(b2))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
# in c/c++
# char = 's';
# printf(char)
c = 's'
c1 = "s"
print(c)
print(c1)
# Out:
# s
# s

# %%
# string
name = "Satyadeep Singh"
print(name)
# Out:
# Satyadeep Singh

# %%
print(id(name))
print(type(name))
# Out:
# 139882507774832
# <class 'str'>

# %%
# string
name1 = 'your name vvgafdasfasfasfa'
type(name1
# Out:
#   File "<ipython-input-5-59c82fbadf5a>", line 3
#     type(name1
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
#complex numbers: note the use of `j` to specify the imaginary part
j = 1.0 + 2.0j
print(j)
# Out:
# (1+2j)

# %%
# print(x.real, x.imag)
print(j.real)
print(j.imag)
# Out:
# 1.0
# 2.0

# %%
print("Hello World")
# Out:
# Hello World

# %%
# how to find area of circle
# area = 3.14*r*r 

r = 4
area = 3.14*r*r

# 1
print(area)
print(type(area))
print(id(area))

# 2
r = 4
print(3.14*r*r)
# Out:
# 50.24
# <class 'float'>
# 139882507686736
# 50.24

# %%
# input output in python
# name = "Satyadeep"
# print("happy birthday "+name)

# name = input()
# print("happy birthday " + name)

name = input("suno tumahra naam kya hai?")
print("happy birthday " + name)
# Out:
# suno tumahra naam kya hai?satyadeep
# happy birthday satyadeep

# %%
a = 5
print(type(a))
b = float(a)  # typecasting
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
# find the area of rectangle
length = int(input("length kya hai: ")) # typecasting
width = int(input("widht kya hai: "))

area = length*width
print(area)
# Out:
# length kya hai: 5
# widht kya hai: 4
# 20

# %%
s1 = "Satyadeep"
s2 = "Singh"
space = " "

# Satyadeep Singh
print(s1+space+s2)
print(s1+" "+s2)
# print("Satyadeep"+" "+"Singh")
# Out:
# Satyadeep Singh
# Satyadeep Singh
# Satyadeep Singh

# %%
print("satyam")
print(" ")
print("satyam" + "singh")
# Out:
# satyam
#
# satyamsingh

# %%
print(1+1)
print("satyadeep"+str(123))
print("satyadeep"+"123")

# a = 4
# b = "4"
# print(a)
# print(type(a))
# print(b)
# print(type(b))
# Out:
# 2
# satyadeep123
# satyadeep123

# %%
c = 4
C = 5
print(c)
print(C)
# Out:
# 4
# 5

# %%
tenth = 10
tenth

# %%
ten = 'ten'
ten

# %%
'Day ' +str(2)
# Out:
# 'Day 2'

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not False
# Out:
# True

# %%
True is False
# Out:
# False

# %%
'a' is 'a'
# Out:
# True

# %%
"satyam" is "satyam"
# Out:
# True

# %%
String_1 = "satyam"
String_2 = "singh"
print(String_1[0])
print(String_1[1])
print(String_1[5])
print(len(String_1)) # length will be lastchar +1
# Out:
# s
# a
# m
# 6

# %%
String_1 = "satybm"
# print(String_1[5])
# print(String_1[-1]) # reverse counting

print(String_1[2])
print(String_1[-4])

print(String_1[-5])
# Out:
# t
# t
# a

# %%
# String slicng
String_1 = "satybm"
print(String_1[0:2])
print(String_1[3:5])
# Out:
# sa
# yb

# %%
String_s = "my name is satyam singh"
print(String_s[11:23])
# Out:
# satyam singh

# %%
print(String_1[0:4:2])
# Out:
# st

# %%
String_s = "satyam"
print(String_s[-2:-4:-1])
# print(String_s[:])
# print(String_s)
# Out:
# ay
